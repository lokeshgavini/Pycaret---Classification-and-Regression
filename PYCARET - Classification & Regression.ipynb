# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from pycaret.datasets import get_data

# %%
#Classification data
diabetes_df=get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
from pycaret.classification import *

# %%
clf=setup(data=diabetes_df,target='Class variable',fold_shuffle=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f8796">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8796_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f8796_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8796_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8796_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_f8796_row0_col1" class="data row0 col1" >7628</td>
#     </tr>
#     <tr>
#       <th id="T_f8796_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8796_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f8796_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_f8796_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f8796_row2_col0" class="data row2 col0" >Target Type</td>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_e8388 th {
#   text-align: left;
# }
# ...

# %%
# From above for the given data Logestic is the best model for Classification.
# We can further work on the model and predict the new values

# %%
# Now lets see the Regression Data
boston_df=get_data('boston')
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
from pycaret.regression import *

# %%
reg=setup(data=boston_df,target='medv',fold_shuffle=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_919e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_919e0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_919e0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_919e0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_919e0_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_919e0_row0_col1" class="data row0 col1" >4273</td>
#     </tr>
#     <tr>
#       <th id="T_919e0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_919e0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_919e0_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_919e0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_919e0_row2_col0" class="data row2 col0" >Original Data</td>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_a4c2d th {
#   text-align: left;
# }
# ...

# %%
#From the above catboost is the best Regressor.
